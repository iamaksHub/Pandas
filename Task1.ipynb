# %% [markdown]
# <a href="https://colab.research.google.com/github/iamaksHub/Pandas/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# titanic data git
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# 1.find ou how many male and female passengers was onboarded.
(len(df[df['Sex']=="male"].index),
len(df[df['Sex']=="female"].index))

# or apply group by and count function

# or

df['Sex'].value_counts() #performs both group by and count operation
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
(len(df[df['Sex']=="male"]),
len(df[df['Sex']=="female"]))
# Out:
# (577, 314)

# %%
df.groupby('Sex').count()  #on each n every column
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
# 2.how many survived we have
len(df[df['Survived']==1])
# len(df[df['Survived']==1].index)
# Out:
# 342

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#3.how many casuality we have(count of 0 in survived column)
len(df[df['Survived']==0].index)
# Out:
# 549

# %%
# 4.what is name of a person who is the eldest one.(age)
ind=df[df['Age']==max(df['Age'])].index
df.loc[ind]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df[df['Age']==df['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df[df['Age']==max(df['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
# 5.how many passenger do we have in first,second and third class(pclass)
(len(df[df['Pclass']==1].index),len(df[df['Pclass']==2].index),len(df[df['Pclass']==3].index))
# Out:
# (216, 184, 491)

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
# 6.how many person we have whose name starts with "s"
len(df[df['Name'].str.startswith("S")])
# Out:
# 86

# %%
# 7.try to create a new column which is a summation of "SibSp" and "parch"
df["SibSpParch"] = df["SibSp"] + df["Parch"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  SibSpParch
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %%
# 8.how many person do we have below age of 25
len(df[df['Age']<25 ])
# Out:
# 278

# %%
# 9.how many person dies whose age was less than 40(age n survived)
ind1 = df[df['Age'] < 40].index
ind2 = df.loc[ind1][df.loc[ind1]['Survived'] == 0].index
# the entire expression df.loc[ind1][df.loc[ind1]['Survived'] == 1].index ultimately provides the
# index labels of rows where both conditions ('Age' less than 40 and 'Survived' equal to 1) are met.
df.loc[ind2]

# or
ind1 = df[df['Age'] < 40].index
ind2 = df.loc[ind1]['Survived'] == 0
df.loc[ind1][ind2]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# ...

# %%
len(df[(df['Survived']==0)& (df["Age"]<40)])
# Out:
# 322

# %%
# 10.from a cabin column seperate text and numeric value
df['cabin_text']=(df['Cabin'].str.extract(r'([a-zA-Z]+)'))
df['cabin_num']=(df['Cabin'].str.extract(r'(\d+)'))

# %%
import re
replace=re.compile("([a-zA-Z]+)")
df['cabin_text']=df['Cabin'].str.extract(replace)
df['cabin_num']=df['Cabin'].str.extract(replace,"") #if string replace it with empty string

# %%
df2=pd.DataFrame(df.Cabin.str.split('([a-zA-Z]+)([^a-zA-])'))

# %%
df2
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 8, 5]
# 2             NaN
# 3    [, C, 1, 23]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 4, 2]
# 888           NaN
# 889  [, C, 1, 48]
# 890           NaN
#
# [891 rows x 1 columns]
